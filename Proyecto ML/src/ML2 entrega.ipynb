# %%
import pandas as pd
df_cars=pd.read_csv(r"C:\Users\Usuario\Documents\Proyecto ML\src\USA_cars_datasets.csv")

# %%
df_cars.drop(columns=['Unnamed: 0','vin', 'lot'],inplace=True)
#df_cars.drop(columns=['vin'],inplace=True)
#df_cars.drop(columns=['lot'],inplace=True)

# %%
df_cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %% [markdown]
# ## Codificación one-hot

# %%
columns_to_encode = ['brand', 'model', 'title_status', 'color', 'state']

df_encoded = pd.get_dummies(df_cars, columns=columns_to_encode, prefix=columns_to_encode)

# %%
from sklearn.preprocessing import LabelEncoder

# encoding a la columna 'condition'
le = LabelEncoder()
df_encoded['condition_encoded'] = le.fit_transform(df_encoded['condition'])
print(df_encoded.head)
# Out:
# <bound method NDFrame.head of       price  year   mileage country      condition  brand_acura  brand_audi  \
# 0      6300  2008  274117.0     usa   10 days left        False       False
# 1      2899  2011  190552.0     usa    6 days left        False       False
# 2      5350  2018   39590.0     usa    2 days left        False       False
# 3     25000  2014   64146.0     usa  22 hours left        False       False
# 4     27700  2018    6654.0     usa  22 hours left        False       False
# ...     ...   ...       ...     ...            ...          ...         ...
# 2494   7800  2019   23609.0     usa    1 days left        False       False
# 2495   9200  2018   34553.0     usa  21 hours left        False       False
# 2496   9200  2018   31594.0     usa  21 hours left        False       False
# 2497   9200  2018   32557.0     usa    2 days left        False       False
# 2498   9200  2018   31371.0     usa  21 hours left        False       False
#
# ...

# %%
import matplotlib.pyplot as plt

years = [2021, 2027]
values = [195.84, 302.47]

plt.figure(figsize=(10, 6))
plt.bar(years, values, color=['blue', 'green'])
plt.title('Mercado de Automóviles en Estados Unidos')
plt.xlabel('Año')
plt.ylabel('Valor en Miles de Millones de Dólares')
plt.ylim(0, 350)

for i, v in enumerate(values):
    plt.text(years[i], v + 5, f'${v}B', ha='center')

plt.show()

# %%
import matplotlib.pyplot as plt

años = [2021, 2027]
valores = [195.85, 302.47]

plt.figure(figsize=(10, 6))
plt.plot(años, valores, marker='o', linewidth=2, color='blue')
plt.title('Proyección del mercado de automóviles en Estados Unidos')
plt.xlabel('Año')
plt.ylabel('Valor en miles de millones de dólares')
plt.grid(True)
plt.annotate(f'${valores[0]} MM', (años[0], valores[0]), textcoords="offset points", xytext=(0,15), ha='center')
plt.annotate(f'${valores[1]} MM', (años[1], valores[1]), textcoords="offset points", xytext=(0,5), ha='center')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Leer el archivo CSV
df = pd.read_csv('USA_cars_datasets.csv')

# Crear el gráfico
plt.figure(figsize=(15, 8))
sns.boxplot(x='state', y='price', data=df)
plt.xticks(rotation=90)
plt.title('Distribución de precios por estado')
plt.xlabel('Estado')
plt.ylabel('Precio (USD)')
plt.show()
